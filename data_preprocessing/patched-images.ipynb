# %%
import shutil
shutil.make_archive('DISCARDED IMAGES', 'zip', '/kaggle/working/DISCARDED')
# Out:
# '/kaggle/working/DISCARDED IMAGES.zip'

# %%
import shutil
shutil.make_archive('SAVED IMAGES', 'zip', '/kaggle/working/SAVE')
# Out:
# '/kaggle/working/SAVED IMAGES.zip'

# %%
rm -rf /kaggle/working/*

# %%
print("ll")
# Out:
# ll

# %%
import os
import cv2
import numpy as np
import time

def process_contour(image, cont, image_name, save_path, patch_size=256, step_size=256, contour_index=0, **kwargs):
    start_x, start_y, w, h = cv2.boundingRect(cont)

    stop_y = start_y + h
    stop_x = start_x + w

    step_size_x = step_size
    step_size_y = step_size

    x_range = np.arange(start_x, stop_x, step=step_size_x)
    y_range = np.arange(start_y, stop_y, step=step_size_y)
    x_coords, y_coords = np.meshgrid(x_range, y_range, indexing='ij')
    coord_candidates = np.array([x_coords.flatten(), y_coords.flatten()]).transpose()

    patch_count = 0
    discard_count = 0
    for coord in coord_candidates:
        x, y = coord
        patch = image[y:y+patch_size, x:x+patch_size]
        gray_patch = cv2.cvtColor(patch, cv2.COLOR_BGR2GRAY)
        variance = np.var(gray_patch)
        thresh = 20
        if patch.shape[0] == patch_size and patch.shape[1] == patch_size:
            if not is_mostly_white_or_black(patch) and variance >= thresh:
                patch_filename = f"{image_name}_{patch_count}.png"
                patch_path = os.path.join(save_path, patch_filename)
                cv2.imwrite(patch_path, patch)
                patch_count += 1

    #print(f"Extracted {patch_count} patches from contour {contour_index}")

def is_mostly_white_or_black(patch, white_threshold=240, black_threshold=20, white_ratio=0.99, black_ratio=0.20, texture_threshold=20, noise_threshold=5, pink_purple_min_ratio=0.02):
    gray_patch = cv2.cvtColor(patch, cv2.COLOR_BGR2GRAY)
    white_pixels = np.sum(gray_patch > white_threshold)
    black_pixels = np.sum(gray_patch < black_threshold)
    total_pixels = gray_patch.size
    white_pixel_ratio = white_pixels / total_pixels
    black_pixel_ratio = black_pixels / total_pixels

    variance = np.var(gray_patch)

    edges = cv2.Canny(gray_patch, 50, 150)
    noise_pixels = np.sum(edges > 0)

    hsv_patch = cv2.cvtColor(patch, cv2.COLOR_BGR2HSV)
    pink_mask = cv2.inRange(hsv_patch, np.array([130, 50, 50]), np.array([180, 255, 255]))
    purple_mask = cv2.inRange(hsv_patch, np.array([120, 50, 50]), np.array([150, 255, 255]))
    pink_purple_pixels = np.sum(pink_mask > 0) + np.sum(purple_mask > 0)
    pink_purple_ratio = pink_purple_pixels / total_pixels

    return (white_pixel_ratio > white_ratio or black_pixel_ratio > black_ratio or noise_pixels > noise_threshold or pink_purple_ratio < pink_purple_min_ratio) and variance < texture_threshold

def process_contours(image, image_name, save_path, patch_size=256, step_size=256, **kwargs):
    image_folder_path = os.path.join(save_path, image_name)
    os.makedirs(image_folder_path, exist_ok=True)

    print(f"Creating patches for: {image_name}")
    elapsed = time.time()
    
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    contours, _ = cv2.findContours(gray, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    n_contours = len(contours)
    #print(f"Total number of contours to process: {n_contours}")
    
    for idx, cont in enumerate(contours):
        #print(f'Processing contour {idx + 1}/{n_contours}')
        process_contour(image, cont, image_name, image_folder_path, patch_size, step_size, idx, **kwargs)
    
    print(f"Time elapsed: {time.time() - elapsed:.2f} seconds")

def patching(image_path, save_path, **kwargs):
    try:
        start_time = time.time()

        image = cv2.imread(image_path)
        if image is None:
            print(f"Error reading {image_path}: Image is None")
            return

        image_name = os.path.splitext(os.path.basename(image_path))[0]
        process_contours(image, image_name, save_path, **kwargs)

        patch_time_elapsed = time.time() - start_time
        print(f"Patching completed for {image_name} in {patch_time_elapsed:.2f} seconds")
    except Exception as e:
        print(f"An error occurred while processing {image_path}: {e}")

def process_folder(input_folder, save_path, **kwargs):
    for filename in os.listdir(input_folder):
        if filename.endswith(".png"):
            image_path = os.path.join(input_folder, filename)
            patching(image_path, save_path, **kwargs)
            
input_folder = "E:\Aamir Gulzar\dataset\cropped_data"
save_path = "E:\Aamir Gulzar\dataset\Patches"
process_folder(input_folder, save_path, patch_size=512, step_size=512)
# Out:
# <>:100: SyntaxWarning: invalid escape sequence '\A'
# <>:101: SyntaxWarning: invalid escape sequence '\A'
# <>:100: SyntaxWarning: invalid escape sequence '\A'
# <>:101: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\DataInsight GPU\AppData\Local\Temp\ipykernel_137724\3828227365.py:100: SyntaxWarning: invalid escape sequence '\A'
#   input_folder = "E:\Aamir Gulzar\dataset\cropped_data"
# C:\Users\DataInsight GPU\AppData\Local\Temp\ipykernel_137724\3828227365.py:101: SyntaxWarning: invalid escape sequence '\A'
#   save_path = "E:\Aamir Gulzar\dataset\Patches"
# Creating patches for: TCGA-3L-AA1B_nonMSIH
# Time elapsed: 15.41 seconds
# Patching completed for TCGA-3L-AA1B_nonMSIH in 19.50 seconds
# Creating patches for: TCGA-4N-A93T_nonMSIH
# Time elapsed: 25.05 seconds
# Patching completed for TCGA-4N-A93T_nonMSIH in 28.68 seconds
# Creating patches for: TCGA-5M-AAT4_nonMSIH
# Time elapsed: 13.23 seconds
# Patching completed for TCGA-5M-AAT4_nonMSIH in 15.83 seconds
# Creating patches for: TCGA-5M-AAT6_MSIH
# Time elapsed: 24.74 seconds
# Patching completed for TCGA-5M-AAT6_MSIH in 29.66 seconds
# Creating patches for: TCGA-5M-AATE_nonMSIH
# Time elapsed: 23.72 seconds
# Patching completed for TCGA-5M-AATE_nonMSIH in 28.37 seconds
# Creating patches for: TCGA-A6-2671_nonMSIH
# Time elapsed: 1.30 seconds
# Patching completed for TCGA-A6-2671_nonMSIH in 1.84 seconds
# Creating patches for: TCGA-A6-2681_nonMSIH
# Time elapsed: 1.62 seconds
# Patching completed for TCGA-A6-2681_nonMSIH in 2.26 seconds
# Creating patches for: TCGA-A6-2685_nonMSIH
# Time elapsed: 8.22 seconds
# Patching completed for TCGA-A6-2685_nonMSIH in 10.17 seconds
# Creating patches for: TCGA-A6-2686_MSIH
# Time elapsed: 4.63 seconds
# Patching completed for TCGA-A6-2686_MSIH in 6.27 seconds
# Creating patches for: TCGA-A6-3807_nonMSIH
# Time elapsed: 4.22 seconds
# Patching completed for TCGA-A6-3807_nonMSIH in 5.42 seconds
# Creating patches for: TCGA-A6-4105_nonMSIH
# Time elapsed: 2.48 seconds
# Patching completed for TCGA-A6-4105_nonMSIH in 3.49 seconds
# Creating patches for: TCGA-A6-4107_nonMSIH
# Time elapsed: 2.21 seconds
# Patching completed for TCGA-A6-4107_nonMSIH in 2.79 seconds
# Creating patches for: TCGA-A6-5657_nonMSIH
# Time elapsed: 5.21 seconds
# Patching completed for TCGA-A6-5657_nonMSIH in 6.04 seconds
# Creating patches for: TCGA-A6-5660_nonMSIH
# Time elapsed: 1.71 seconds
# Patching completed for TCGA-A6-5660_nonMSIH in 2.47 seconds
# Creating patches for: TCGA-A6-5661_MSIH
# Time elapsed: 1.81 seconds
# Patching completed for TCGA-A6-5661_MSIH in 2.27 seconds
# Creating patches for: TCGA-A6-5662_nonMSIH
# Time elapsed: 1.51 seconds
# Patching completed for TCGA-A6-5662_nonMSIH in 1.90 seconds
# Creating patches for: TCGA-A6-5664_nonMSIH
# Time elapsed: 4.11 seconds
# Patching completed for TCGA-A6-5664_nonMSIH in 5.69 seconds
# Creating patches for: TCGA-A6-5665_MSIH
# Time elapsed: 2.17 seconds
# Patching completed for TCGA-A6-5665_MSIH in 2.79 seconds
# Creating patches for: TCGA-A6-5666_nonMSIH
# Time elapsed: 6.14 seconds
# Patching completed for TCGA-A6-5666_nonMSIH in 7.61 seconds
# Creating patches for: TCGA-A6-5667_nonMSIH
# Time elapsed: 1.28 seconds
# Patching completed for TCGA-A6-5667_nonMSIH in 1.55 seconds
# Creating patches for: TCGA-A6-6137_nonMSIH
# Time elapsed: 9.63 seconds
# Patching completed for TCGA-A6-6137_nonMSIH in 10.46 seconds
# Creating patches for: TCGA-A6-6138_nonMSIH
# Time elapsed: 4.07 seconds
# Patching completed for TCGA-A6-6138_nonMSIH in 4.66 seconds
# Creating patches for: TCGA-A6-6142_nonMSIH
# Time elapsed: 4.14 seconds
# Patching completed for TCGA-A6-6142_nonMSIH in 4.71 seconds
# Creating patches for: TCGA-A6-6648_nonMSIH
# Time elapsed: 1.15 seconds
# Patching completed for TCGA-A6-6648_nonMSIH in 1.41 seconds
# Creating patches for: TCGA-A6-6649_nonMSIH
# Time elapsed: 1.87 seconds
# Patching completed for TCGA-A6-6649_nonMSIH in 2.44 seconds
# Creating patches for: TCGA-A6-6651_nonMSIH
# Time elapsed: 2.44 seconds
# Patching completed for TCGA-A6-6651_nonMSIH in 2.88 seconds
# Creating patches for: TCGA-A6-6652_nonMSIH
# Time elapsed: 0.72 seconds
# Patching completed for TCGA-A6-6652_nonMSIH in 0.89 seconds
# Creating patches for: TCGA-A6-6653_MSIH
# Time elapsed: 2.02 seconds
# Patching completed for TCGA-A6-6653_MSIH in 2.55 seconds
# Creating patches for: TCGA-A6-6654_nonMSIH
# Time elapsed: 4.49 seconds
# Patching completed for TCGA-A6-6654_nonMSIH in 32.16 seconds
# Creating patches for: TCGA-A6-A565_nonMSIH
# Time elapsed: 2.85 seconds
# Patching completed for TCGA-A6-A565_nonMSIH in 20.95 seconds
# Creating patches for: TCGA-A6-A566_nonMSIH
# Time elapsed: 2.25 seconds
# Patching completed for TCGA-A6-A566_nonMSIH in 9.67 seconds
# Creating patches for: TCGA-A6-A567_nonMSIH
# Time elapsed: 22.35 seconds
# Patching completed for TCGA-A6-A567_nonMSIH in 40.05 seconds
# Creating patches for: TCGA-A6-A56B_nonMSIH
# Time elapsed: 8.02 seconds
# Patching completed for TCGA-A6-A56B_nonMSIH in 10.58 seconds
# Creating patches for: TCGA-AA-3664_nonMSIH
# Time elapsed: 7.82 seconds
# Patching completed for TCGA-AA-3664_nonMSIH in 41.01 seconds
# Creating patches for: TCGA-AA-3666_nonMSIH
# Time elapsed: 7.06 seconds
# Patching completed for TCGA-AA-3666_nonMSIH in 23.91 seconds
# Creating patches for: TCGA-AA-3667_nonMSIH
# Time elapsed: 6.89 seconds
# Patching completed for TCGA-AA-3667_nonMSIH in 12.57 seconds
# Creating patches for: TCGA-AA-3673_nonMSIH
# Time elapsed: 2.25 seconds
# Patching completed for TCGA-AA-3673_nonMSIH in 3.85 seconds
# Creating patches for: TCGA-AA-3678_nonMSIH
# Time elapsed: 4.62 seconds
# Patching completed for TCGA-AA-3678_nonMSIH in 8.45 seconds
# Creating patches for: TCGA-AA-3679_nonMSIH
# Time elapsed: 3.30 seconds
# Patching completed for TCGA-AA-3679_nonMSIH in 20.39 seconds
# Creating patches for: TCGA-AA-3680_nonMSIH
# Time elapsed: 1.07 seconds
# Patching completed for TCGA-AA-3680_nonMSIH in 8.02 seconds
# Creating patches for: TCGA-AA-3681_nonMSIH
# Time elapsed: 0.18 seconds
# Patching completed for TCGA-AA-3681_nonMSIH in 0.27 seconds
# Creating patches for: TCGA-AA-3684_nonMSIH
# Time elapsed: 15.20 seconds
# Patching completed for TCGA-AA-3684_nonMSIH in 71.26 seconds
# Creating patches for: TCGA-AA-3688_nonMSIH
# Time elapsed: 12.44 seconds
# Patching completed for TCGA-AA-3688_nonMSIH in 40.79 seconds
# Creating patches for: TCGA-AA-3692_nonMSIH
# Time elapsed: 7.21 seconds
# Patching completed for TCGA-AA-3692_nonMSIH in 17.69 seconds
# Creating patches for: TCGA-AA-3693_nonMSIH
# Time elapsed: 26.31 seconds
# Patching completed for TCGA-AA-3693_nonMSIH in 44.95 seconds
# Creating patches for: TCGA-AA-3696_nonMSIH
# Time elapsed: 7.07 seconds
# Patching completed for TCGA-AA-3696_nonMSIH in 12.16 seconds
# Creating patches for: TCGA-AA-3715_MSIH
# Time elapsed: 17.82 seconds
# Patching completed for TCGA-AA-3715_MSIH in 27.22 seconds
# Creating patches for: TCGA-AA-3811_MSIH
# Time elapsed: 6.59 seconds
# Patching completed for TCGA-AA-3811_MSIH in 13.15 seconds
# Creating patches for: TCGA-AA-3812_nonMSIH
# Time elapsed: 1.65 seconds
# Patching completed for TCGA-AA-3812_nonMSIH in 8.18 seconds
# Creating patches for: TCGA-AA-3814_nonMSIH
# Time elapsed: 0.48 seconds
# Patching completed for TCGA-AA-3814_nonMSIH in 0.68 seconds
# Creating patches for: TCGA-AA-3818_nonMSIH
# Time elapsed: 1.50 seconds
# Patching completed for TCGA-AA-3818_nonMSIH in 6.22 seconds
# Creating patches for: TCGA-AA-3819_nonMSIH
# Time elapsed: 5.97 seconds
# Patching completed for TCGA-AA-3819_nonMSIH in 11.90 seconds
# Creating patches for: TCGA-AA-3821_MSIH
# Time elapsed: 5.62 seconds
# Patching completed for TCGA-AA-3821_MSIH in 11.70 seconds
# Creating patches for: TCGA-AA-3831_nonMSIH
# Time elapsed: 13.66 seconds
# Patching completed for TCGA-AA-3831_nonMSIH in 25.91 seconds
# Creating patches for: TCGA-AA-3833_MSIH
# Time elapsed: 5.20 seconds
# Patching completed for TCGA-AA-3833_MSIH in 5.45 seconds
# Creating patches for: TCGA-AA-3837_nonMSIH
# Time elapsed: 5.79 seconds
# Patching completed for TCGA-AA-3837_nonMSIH in 12.22 seconds
# Creating patches for: TCGA-AA-3842_nonMSIH
# Time elapsed: 2.30 seconds
# Patching completed for TCGA-AA-3842_nonMSIH in 5.32 seconds
# Creating patches for: TCGA-AA-3844_nonMSIH
# Time elapsed: 2.99 seconds
# Patching completed for TCGA-AA-3844_nonMSIH in 6.20 seconds
# Creating patches for: TCGA-AA-3845_MSIH
# Time elapsed: 1.82 seconds
# Patching completed for TCGA-AA-3845_MSIH in 3.39 seconds
# Creating patches for: TCGA-AA-3846_nonMSIH
# Time elapsed: 2.32 seconds
# Patching completed for TCGA-AA-3846_nonMSIH in 2.43 seconds
# Creating patches for: TCGA-AA-3848_nonMSIH
# Time elapsed: 8.55 seconds
# Patching completed for TCGA-AA-3848_nonMSIH in 15.36 seconds
# Creating patches for: TCGA-AA-3850_nonMSIH
# Time elapsed: 10.95 seconds
# Patching completed for TCGA-AA-3850_nonMSIH in 18.90 seconds
# Creating patches for: TCGA-AA-3851_nonMSIH
# Time elapsed: 10.66 seconds
# Patching completed for TCGA-AA-3851_nonMSIH in 16.27 seconds
# Creating patches for: TCGA-AA-3852_nonMSIH
# Time elapsed: 7.69 seconds
# Patching completed for TCGA-AA-3852_nonMSIH in 13.57 seconds
# Creating patches for: TCGA-AA-3854_nonMSIH
# Time elapsed: 3.31 seconds
# Patching completed for TCGA-AA-3854_nonMSIH in 5.70 seconds
# Creating patches for: TCGA-AA-3855_nonMSIH
# Time elapsed: 12.98 seconds
# Patching completed for TCGA-AA-3855_nonMSIH in 17.73 seconds
# Creating patches for: TCGA-AA-3856_nonMSIH
# Time elapsed: 24.06 seconds
# Patching completed for TCGA-AA-3856_nonMSIH in 43.33 seconds
# Creating patches for: TCGA-AA-3858_nonMSIH
# Time elapsed: 3.33 seconds
# Patching completed for TCGA-AA-3858_nonMSIH in 5.72 seconds
# Creating patches for: TCGA-AA-3864_MSIH
# Time elapsed: 1.09 seconds
# Patching completed for TCGA-AA-3864_MSIH in 1.67 seconds
# Creating patches for: TCGA-AA-3866_nonMSIH
# Time elapsed: 7.48 seconds
# Patching completed for TCGA-AA-3866_nonMSIH in 13.32 seconds
# Creating patches for: TCGA-AA-3867_nonMSIH
# Time elapsed: 8.39 seconds
# Patching completed for TCGA-AA-3867_nonMSIH in 13.26 seconds
# Creating patches for: TCGA-AA-3875_nonMSIH
# Time elapsed: 16.32 seconds
# Patching completed for TCGA-AA-3875_nonMSIH in 24.90 seconds
# Creating patches for: TCGA-AA-3877_MSIH
# Time elapsed: 18.08 seconds
# Patching completed for TCGA-AA-3877_MSIH in 28.60 seconds
# Creating patches for: TCGA-AA-3947_MSIH
# Time elapsed: 10.60 seconds
# Patching completed for TCGA-AA-3947_MSIH in 17.75 seconds
# Creating patches for: TCGA-AA-3949_MSIH
# Time elapsed: 2.04 seconds
# Patching completed for TCGA-AA-3949_MSIH in 9.66 seconds
# Creating patches for: TCGA-AA-3950_MSIH
# Time elapsed: 0.80 seconds
# Patching completed for TCGA-AA-3950_MSIH in 1.14 seconds
# Creating patches for: TCGA-AA-3952_nonMSIH
# Time elapsed: 0.84 seconds
# Patching completed for TCGA-AA-3952_nonMSIH in 1.20 seconds
# Creating patches for: TCGA-AA-3956_nonMSIH
# Time elapsed: 2.90 seconds
# Patching completed for TCGA-AA-3956_nonMSIH in 4.27 seconds
# Creating patches for: TCGA-AA-3966_MSIH
# Time elapsed: 0.06 seconds
# Patching completed for TCGA-AA-3966_MSIH in 0.10 seconds
# Creating patches for: TCGA-AA-3968_nonMSIH
# Time elapsed: 1.02 seconds
# Patching completed for TCGA-AA-3968_nonMSIH in 1.47 seconds
# Creating patches for: TCGA-AA-3971_nonMSIH
# Time elapsed: 10.96 seconds
# Patching completed for TCGA-AA-3971_nonMSIH in 15.31 seconds
# Creating patches for: TCGA-AA-3973_nonMSIH
# Time elapsed: 1.69 seconds
# Patching completed for TCGA-AA-3973_nonMSIH in 2.34 seconds
# Creating patches for: TCGA-AA-3975_nonMSIH
# Time elapsed: 2.03 seconds
# Patching completed for TCGA-AA-3975_nonMSIH in 2.79 seconds
# Creating patches for: TCGA-AA-3976_nonMSIH
# Time elapsed: 0.68 seconds
# Patching completed for TCGA-AA-3976_nonMSIH in 1.00 seconds
# Creating patches for: TCGA-AA-3979_nonMSIH
# Time elapsed: 1.00 seconds
# Patching completed for TCGA-AA-3979_nonMSIH in 1.48 seconds
# Creating patches for: TCGA-AA-3982_nonMSIH
# Time elapsed: 2.38 seconds
# Patching completed for TCGA-AA-3982_nonMSIH in 3.25 seconds
# Creating patches for: TCGA-AA-3984_nonMSIH
# Time elapsed: 1.71 seconds
# Patching completed for TCGA-AA-3984_nonMSIH in 3.11 seconds
# Creating patches for: TCGA-AA-3986_nonMSIH
# Time elapsed: 8.44 seconds
# Patching completed for TCGA-AA-3986_nonMSIH in 11.49 seconds
# Creating patches for: TCGA-AA-3989_nonMSIH
# Time elapsed: 1.25 seconds
# Patching completed for TCGA-AA-3989_nonMSIH in 1.87 seconds
# Creating patches for: TCGA-AA-3994_nonMSIH
# Time elapsed: 1.58 seconds
# Patching completed for TCGA-AA-3994_nonMSIH in 2.21 seconds
# Creating patches for: TCGA-AA-A010_nonMSIH
# Time elapsed: 5.83 seconds
# Patching completed for TCGA-AA-A010_nonMSIH in 8.41 seconds
# Creating patches for: TCGA-AA-A01P_MSIH
# Time elapsed: 3.41 seconds
# Patching completed for TCGA-AA-A01P_MSIH in 5.18 seconds
# Creating patches for: TCGA-AA-A01R_MSIH
# Time elapsed: 6.39 seconds
# Patching completed for TCGA-AA-A01R_MSIH in 13.01 seconds
# Creating patches for: TCGA-AA-A01S_nonMSIH
# Time elapsed: 2.76 seconds
# Patching completed for TCGA-AA-A01S_nonMSIH in 4.19 seconds
# Creating patches for: TCGA-AA-A01T_nonMSIH
# Time elapsed: 2.42 seconds
# Patching completed for TCGA-AA-A01T_nonMSIH in 5.08 seconds
# Creating patches for: TCGA-AA-A01V_nonMSIH
# Time elapsed: 9.58 seconds
# Patching completed for TCGA-AA-A01V_nonMSIH in 13.63 seconds
# Creating patches for: TCGA-AA-A01X_nonMSIH
# Time elapsed: 4.70 seconds
# Patching completed for TCGA-AA-A01X_nonMSIH in 6.36 seconds
# Creating patches for: TCGA-AA-A01Z_nonMSIH
# Time elapsed: 3.92 seconds
# Patching completed for TCGA-AA-A01Z_nonMSIH in 9.72 seconds
# Creating patches for: TCGA-AA-A024_nonMSIH
# Time elapsed: 4.48 seconds
# Patching completed for TCGA-AA-A024_nonMSIH in 6.65 seconds
# Creating patches for: TCGA-AA-A02E_nonMSIH
# Time elapsed: 1.47 seconds
# Patching completed for TCGA-AA-A02E_nonMSIH in 2.22 seconds
# Creating patches for: TCGA-AA-A02F_nonMSIH
# Time elapsed: 4.23 seconds
# Patching completed for TCGA-AA-A02F_nonMSIH in 6.62 seconds
# Creating patches for: TCGA-AA-A02H_nonMSIH
# Time elapsed: 2.41 seconds
# Patching completed for TCGA-AA-A02H_nonMSIH in 6.06 seconds
# Creating patches for: TCGA-AA-A02O_nonMSIH
# Time elapsed: 2.94 seconds
# Patching completed for TCGA-AA-A02O_nonMSIH in 4.54 seconds
# Creating patches for: TCGA-AA-A02Y_nonMSIH
# Time elapsed: 2.90 seconds
# Patching completed for TCGA-AA-A02Y_nonMSIH in 4.11 seconds
# Creating patches for: TCGA-AA-A03F_nonMSIH
# Time elapsed: 0.25 seconds
# Patching completed for TCGA-AA-A03F_nonMSIH in 0.35 seconds
# Creating patches for: TCGA-AA-A03J_nonMSIH
# Time elapsed: 4.49 seconds
# Patching completed for TCGA-AA-A03J_nonMSIH in 7.19 seconds
# Creating patches for: TCGA-AD-5900_MSIH
# Time elapsed: 1.82 seconds
# Patching completed for TCGA-AD-5900_MSIH in 4.97 seconds
# Creating patches for: TCGA-AD-6548_nonMSIH
# Time elapsed: 1.49 seconds
# Patching completed for TCGA-AD-6548_nonMSIH in 2.18 seconds
# Creating patches for: TCGA-AD-6888_nonMSIH
# Time elapsed: 3.05 seconds
# Patching completed for TCGA-AD-6888_nonMSIH in 4.36 seconds
# Creating patches for: TCGA-AD-6889_MSIH
# Time elapsed: 7.58 seconds
# Patching completed for TCGA-AD-6889_MSIH in 11.00 seconds
# Creating patches for: TCGA-AD-6890_nonMSIH
# Time elapsed: 1.09 seconds
# Patching completed for TCGA-AD-6890_nonMSIH in 2.21 seconds
# Creating patches for: TCGA-AD-6895_MSIH
# Time elapsed: 0.53 seconds
# Patching completed for TCGA-AD-6895_MSIH in 0.80 seconds
# Creating patches for: TCGA-AD-6899_nonMSIH
# Time elapsed: 0.86 seconds
# Patching completed for TCGA-AD-6899_nonMSIH in 1.26 seconds
# Creating patches for: TCGA-AD-6901_nonMSIH
# Time elapsed: 1.79 seconds
# Patching completed for TCGA-AD-6901_nonMSIH in 7.75 seconds
# Creating patches for: TCGA-AD-6963_nonMSIH
# Time elapsed: 1.14 seconds
# Patching completed for TCGA-AD-6963_nonMSIH in 1.65 seconds
# Creating patches for: TCGA-AD-6964_MSIH
# Time elapsed: 4.63 seconds
# Patching completed for TCGA-AD-6964_MSIH in 6.64 seconds
# Creating patches for: TCGA-AD-6965_nonMSIH
# Time elapsed: 1.38 seconds
# Patching completed for TCGA-AD-6965_nonMSIH in 1.90 seconds
# Creating patches for: TCGA-AD-A5EJ_MSIH
# Time elapsed: 1.84 seconds
# Patching completed for TCGA-AD-A5EJ_MSIH in 3.42 seconds
# Creating patches for: TCGA-AD-A5EK_nonMSIH
# Time elapsed: 4.31 seconds
# Patching completed for TCGA-AD-A5EK_nonMSIH in 8.74 seconds
# Creating patches for: TCGA-AF-2687_nonMSIH
# Time elapsed: 2.43 seconds
# Patching completed for TCGA-AF-2687_nonMSIH in 3.62 seconds
# Creating patches for: TCGA-AF-2693_nonMSIH
# Time elapsed: 0.80 seconds
# Patching completed for TCGA-AF-2693_nonMSIH in 1.20 seconds
# Creating patches for: TCGA-AF-3911_nonMSIH
# Time elapsed: 1.40 seconds
# Patching completed for TCGA-AF-3911_nonMSIH in 2.03 seconds
# Creating patches for: TCGA-AF-4110_nonMSIH
# Time elapsed: 2.62 seconds
# Patching completed for TCGA-AF-4110_nonMSIH in 3.78 seconds
# Creating patches for: TCGA-AF-6136_nonMSIH
# Time elapsed: 2.51 seconds
# Patching completed for TCGA-AF-6136_nonMSIH in 3.63 seconds
# Creating patches for: TCGA-AF-6655_nonMSIH
# Time elapsed: 1.25 seconds
# Patching completed for TCGA-AF-6655_nonMSIH in 2.56 seconds
# Creating patches for: TCGA-AF-6672_nonMSIH
# Time elapsed: 3.68 seconds
# Patching completed for TCGA-AF-6672_nonMSIH in 5.56 seconds
# Creating patches for: TCGA-AF-A56L_nonMSIH
# Time elapsed: 3.61 seconds
# Patching completed for TCGA-AF-A56L_nonMSIH in 5.18 seconds
# Creating patches for: TCGA-AF-A56N_nonMSIH
# Time elapsed: 0.59 seconds
# Patching completed for TCGA-AF-A56N_nonMSIH in 0.98 seconds
# Creating patches for: TCGA-AG-3726_nonMSIH
# Time elapsed: 0.31 seconds
# Patching completed for TCGA-AG-3726_nonMSIH in 3.79 seconds
# Creating patches for: TCGA-AG-3727_nonMSIH
# Time elapsed: 0.38 seconds
# Patching completed for TCGA-AG-3727_nonMSIH in 0.76 seconds
# Creating patches for: TCGA-AG-3878_nonMSIH
# Time elapsed: 0.89 seconds
# Patching completed for TCGA-AG-3878_nonMSIH in 1.27 seconds
# Creating patches for: TCGA-AG-3882_nonMSIH
# Time elapsed: 0.64 seconds
# Patching completed for TCGA-AG-3882_nonMSIH in 0.92 seconds
# Creating patches for: TCGA-AG-3883_nonMSIH
# Time elapsed: 5.20 seconds
# Patching completed for TCGA-AG-3883_nonMSIH in 6.95 seconds
# Creating patches for: TCGA-AG-3885_nonMSIH
# Time elapsed: 0.83 seconds
# Patching completed for TCGA-AG-3885_nonMSIH in 1.19 seconds
# Creating patches for: TCGA-AG-3887_nonMSIH
# Time elapsed: 0.90 seconds
# Patching completed for TCGA-AG-3887_nonMSIH in 1.28 seconds
# Creating patches for: TCGA-AG-3890_nonMSIH
# Time elapsed: 4.58 seconds
# Patching completed for TCGA-AG-3890_nonMSIH in 6.23 seconds
# Creating patches for: TCGA-AG-3892_nonMSIH
# Time elapsed: 6.95 seconds
# Patching completed for TCGA-AG-3892_nonMSIH in 10.07 seconds
# Creating patches for: TCGA-AG-3893_nonMSIH
# Time elapsed: 1.55 seconds
# Patching completed for TCGA-AG-3893_nonMSIH in 2.17 seconds
# Creating patches for: TCGA-AG-3894_nonMSIH
# Time elapsed: 0.14 seconds
# Patching completed for TCGA-AG-3894_nonMSIH in 0.20 seconds
# Creating patches for: TCGA-AG-3896_nonMSIH
# Time elapsed: 0.50 seconds
# Patching completed for TCGA-AG-3896_nonMSIH in 0.80 seconds
# Creating patches for: TCGA-AG-3898_nonMSIH
# Time elapsed: 1.06 seconds
# Patching completed for TCGA-AG-3898_nonMSIH in 1.48 seconds
# Creating patches for: TCGA-AG-3901_nonMSIH
# Time elapsed: 1.06 seconds
# Patching completed for TCGA-AG-3901_nonMSIH in 1.51 seconds
# Creating patches for: TCGA-AG-3902_nonMSIH
# Time elapsed: 1.13 seconds
# Patching completed for TCGA-AG-3902_nonMSIH in 1.68 seconds
# Creating patches for: TCGA-AG-3909_nonMSIH
# Time elapsed: 1.28 seconds
# Patching completed for TCGA-AG-3909_nonMSIH in 1.77 seconds
# Creating patches for: TCGA-AG-4001_nonMSIH
# Time elapsed: 2.48 seconds
# Patching completed for TCGA-AG-4001_nonMSIH in 3.71 seconds
# Creating patches for: TCGA-AG-4008_nonMSIH
# Time elapsed: 0.32 seconds
# Patching completed for TCGA-AG-4008_nonMSIH in 0.45 seconds
# Creating patches for: TCGA-AG-4015_nonMSIH
# Time elapsed: 0.48 seconds
# Patching completed for TCGA-AG-4015_nonMSIH in 0.70 seconds
# Creating patches for: TCGA-AG-4021_nonMSIH
# Time elapsed: 3.86 seconds
# Patching completed for TCGA-AG-4021_nonMSIH in 8.14 seconds
# Creating patches for: TCGA-AG-4022_nonMSIH
# Time elapsed: 1.60 seconds
# Patching completed for TCGA-AG-4022_nonMSIH in 2.33 seconds
# Creating patches for: TCGA-AG-A002_nonMSIH
# Time elapsed: 1.69 seconds
# Patching completed for TCGA-AG-A002_nonMSIH in 2.36 seconds
# Creating patches for: TCGA-AG-A008_nonMSIH
# Time elapsed: 4.42 seconds
# Patching completed for TCGA-AG-A008_nonMSIH in 6.71 seconds
# Creating patches for: TCGA-AG-A00C_nonMSIH
# Time elapsed: 2.18 seconds
# Patching completed for TCGA-AG-A00C_nonMSIH in 6.00 seconds
# Creating patches for: TCGA-AG-A011_nonMSIH
# Time elapsed: 2.92 seconds
# Patching completed for TCGA-AG-A011_nonMSIH in 4.13 seconds
# Creating patches for: TCGA-AG-A015_nonMSIH
# Time elapsed: 1.63 seconds
# Patching completed for TCGA-AG-A015_nonMSIH in 2.31 seconds
# Creating patches for: TCGA-AG-A016_nonMSIH
# Time elapsed: 1.15 seconds
# Patching completed for TCGA-AG-A016_nonMSIH in 1.53 seconds
# Creating patches for: TCGA-AG-A01L_nonMSIH
# Time elapsed: 0.42 seconds
# Patching completed for TCGA-AG-A01L_nonMSIH in 0.80 seconds
# Creating patches for: TCGA-AG-A01N_nonMSIH
# Time elapsed: 0.82 seconds
# Patching completed for TCGA-AG-A01N_nonMSIH in 1.33 seconds
# Creating patches for: TCGA-AG-A01W_nonMSIH
# Time elapsed: 3.91 seconds
# Patching completed for TCGA-AG-A01W_nonMSIH in 6.37 seconds
# Creating patches for: TCGA-AG-A01Y_nonMSIH
# Time elapsed: 8.97 seconds
# Patching completed for TCGA-AG-A01Y_nonMSIH in 13.33 seconds
# Creating patches for: TCGA-AG-A020_nonMSIH
# Time elapsed: 1.19 seconds
# Patching completed for TCGA-AG-A020_nonMSIH in 2.01 seconds
# Creating patches for: TCGA-AG-A026_nonMSIH
# Time elapsed: 0.60 seconds
# Patching completed for TCGA-AG-A026_nonMSIH in 0.90 seconds
# Creating patches for: TCGA-AG-A02N_MSIH
# Time elapsed: 1.27 seconds
# Patching completed for TCGA-AG-A02N_MSIH in 1.91 seconds
# Creating patches for: TCGA-AG-A02X_nonMSIH
# Time elapsed: 0.61 seconds
# Patching completed for TCGA-AG-A02X_nonMSIH in 0.88 seconds
# Creating patches for: TCGA-AH-6544_nonMSIH
# Time elapsed: 3.65 seconds
# Patching completed for TCGA-AH-6544_nonMSIH in 5.51 seconds
# Creating patches for: TCGA-AH-6547_nonMSIH
# Time elapsed: 0.71 seconds
# Patching completed for TCGA-AH-6547_nonMSIH in 1.14 seconds
# Creating patches for: TCGA-AH-6643_nonMSIH
# Time elapsed: 4.12 seconds
# Patching completed for TCGA-AH-6643_nonMSIH in 6.86 seconds
# Creating patches for: TCGA-AH-6644_nonMSIH
# Time elapsed: 2.03 seconds
# Patching completed for TCGA-AH-6644_nonMSIH in 6.46 seconds
# Creating patches for: TCGA-AH-6897_nonMSIH
# Time elapsed: 2.78 seconds
# Patching completed for TCGA-AH-6897_nonMSIH in 3.84 seconds
# Creating patches for: TCGA-AH-6903_nonMSIH
# Time elapsed: 3.05 seconds
# Patching completed for TCGA-AH-6903_nonMSIH in 4.59 seconds
# Creating patches for: TCGA-AM-5820_nonMSIH
# Time elapsed: 5.34 seconds
# Patching completed for TCGA-AM-5820_nonMSIH in 7.73 seconds
# Creating patches for: TCGA-AM-5821_MSIH
# Time elapsed: 6.25 seconds
# Patching completed for TCGA-AM-5821_MSIH in 10.50 seconds
# Creating patches for: TCGA-AU-3779_nonMSIH
# Time elapsed: 1.69 seconds
# Patching completed for TCGA-AU-3779_nonMSIH in 3.31 seconds
# Creating patches for: TCGA-AU-6004_MSIH
# Time elapsed: 1.19 seconds
# Patching completed for TCGA-AU-6004_MSIH in 2.03 seconds
# Creating patches for: TCGA-AY-4070_nonMSIH
# Time elapsed: 0.33 seconds
# Patching completed for TCGA-AY-4070_nonMSIH in 0.48 seconds
# Creating patches for: TCGA-AY-4071_nonMSIH
# Time elapsed: 1.52 seconds
# Patching completed for TCGA-AY-4071_nonMSIH in 2.67 seconds
# Creating patches for: TCGA-AY-5543_nonMSIH
# Time elapsed: 4.80 seconds
# Patching completed for TCGA-AY-5543_nonMSIH in 7.76 seconds
# Creating patches for: TCGA-AY-6196_nonMSIH
# Time elapsed: 12.40 seconds
# Patching completed for TCGA-AY-6196_nonMSIH in 20.48 seconds
# Creating patches for: TCGA-AY-6197_MSIH
# Time elapsed: 5.21 seconds
# Patching completed for TCGA-AY-6197_MSIH in 12.01 seconds
# Creating patches for: TCGA-AY-6386_nonMSIH
# Time elapsed: 3.33 seconds
# Patching completed for TCGA-AY-6386_nonMSIH in 5.01 seconds
# Creating patches for: TCGA-AY-A54L_nonMSIH
# Time elapsed: 4.04 seconds
# Patching completed for TCGA-AY-A54L_nonMSIH in 6.60 seconds
# Creating patches for: TCGA-AY-A69D_nonMSIH
# Time elapsed: 2.78 seconds
# Patching completed for TCGA-AY-A69D_nonMSIH in 4.45 seconds
# Creating patches for: TCGA-AY-A8YK_nonMSIH
# Time elapsed: 2.61 seconds
# Patching completed for TCGA-AY-A8YK_nonMSIH in 8.53 seconds
# Creating patches for: TCGA-AZ-4308_nonMSIH
# Time elapsed: 10.50 seconds
# Patching completed for TCGA-AZ-4308_nonMSIH in 14.85 seconds
# Creating patches for: TCGA-AZ-4315_nonMSIH
# Time elapsed: 23.45 seconds
# Patching completed for TCGA-AZ-4315_nonMSIH in 29.22 seconds
# Creating patches for: TCGA-AZ-4614_nonMSIH
# Time elapsed: 19.19 seconds
# Patching completed for TCGA-AZ-4614_nonMSIH in 24.43 seconds
# Creating patches for: TCGA-AZ-4615_MSIH
# Time elapsed: 16.24 seconds
# Patching completed for TCGA-AZ-4615_MSIH in 23.05 seconds
# Creating patches for: TCGA-AZ-4616_nonMSIH
# Time elapsed: 11.21 seconds
# Patching completed for TCGA-AZ-4616_nonMSIH in 18.93 seconds
# Creating patches for: TCGA-AZ-4681_nonMSIH
# Time elapsed: 10.45 seconds
# Patching completed for TCGA-AZ-4681_nonMSIH in 20.02 seconds
# Creating patches for: TCGA-AZ-4682_nonMSIH
# Time elapsed: 14.02 seconds
# Patching completed for TCGA-AZ-4682_nonMSIH in 19.03 seconds
# Creating patches for: TCGA-AZ-5403_nonMSIH
# Time elapsed: 10.77 seconds
# Patching completed for TCGA-AZ-5403_nonMSIH in 21.65 seconds
# Creating patches for: TCGA-AZ-5407_nonMSIH
# Time elapsed: 6.04 seconds
# Patching completed for TCGA-AZ-5407_nonMSIH in 13.67 seconds
# Creating patches for: TCGA-AZ-6598_MSIH
# Time elapsed: 11.38 seconds
# Patching completed for TCGA-AZ-6598_MSIH in 17.99 seconds
# Creating patches for: TCGA-AZ-6599_nonMSIH
# Time elapsed: 10.34 seconds
# Patching completed for TCGA-AZ-6599_nonMSIH in 18.72 seconds
# Creating patches for: TCGA-AZ-6600_nonMSIH
# Time elapsed: 19.22 seconds
# Patching completed for TCGA-AZ-6600_nonMSIH in 25.59 seconds
# Creating patches for: TCGA-AZ-6603_nonMSIH
# Time elapsed: 15.87 seconds
# Patching completed for TCGA-AZ-6603_nonMSIH in 21.31 seconds
# Creating patches for: TCGA-AZ-6605_nonMSIH
# Time elapsed: 17.76 seconds
# Patching completed for TCGA-AZ-6605_nonMSIH in 26.95 seconds
# Creating patches for: TCGA-AZ-6606_nonMSIH
# Time elapsed: 13.35 seconds
# Patching completed for TCGA-AZ-6606_nonMSIH in 20.36 seconds
# Creating patches for: TCGA-CA-5254_nonMSIH
# Time elapsed: 6.88 seconds
# Patching completed for TCGA-CA-5254_nonMSIH in 15.24 seconds
# Creating patches for: TCGA-CA-5255_nonMSIH
# Time elapsed: 11.69 seconds
# Patching completed for TCGA-CA-5255_nonMSIH in 16.06 seconds
# Creating patches for: TCGA-CA-5256_nonMSIH
# Time elapsed: 5.58 seconds
# Patching completed for TCGA-CA-5256_nonMSIH in 8.07 seconds
# Creating patches for: TCGA-CA-5796_nonMSIH
# Time elapsed: 15.21 seconds
# Patching completed for TCGA-CA-5796_nonMSIH in 20.38 seconds
# Creating patches for: TCGA-CA-5797_nonMSIH
# Time elapsed: 7.70 seconds
# Patching completed for TCGA-CA-5797_nonMSIH in 12.10 seconds
# Creating patches for: TCGA-CA-6715_nonMSIH
# Time elapsed: 13.17 seconds
# Patching completed for TCGA-CA-6715_nonMSIH in 20.37 seconds
# Creating patches for: TCGA-CA-6716_nonMSIH
# Time elapsed: 10.57 seconds
# Patching completed for TCGA-CA-6716_nonMSIH in 20.71 seconds
# Creating patches for: TCGA-CA-6717_nonMSIH
# Time elapsed: 7.44 seconds
# Patching completed for TCGA-CA-6717_nonMSIH in 14.72 seconds
# Creating patches for: TCGA-CA-6718_nonMSIH
# Time elapsed: 10.09 seconds
# Patching completed for TCGA-CA-6718_nonMSIH in 15.41 seconds
# Creating patches for: TCGA-CA-6719_nonMSIH
# Time elapsed: 8.25 seconds
# Patching completed for TCGA-CA-6719_nonMSIH in 16.23 seconds
# Creating patches for: TCGA-CI-6622_nonMSIH
# Time elapsed: 0.19 seconds
# Patching completed for TCGA-CI-6622_nonMSIH in 0.31 seconds
# Creating patches for: TCGA-CK-4947_nonMSIH
# Time elapsed: 20.36 seconds
# Patching completed for TCGA-CK-4947_nonMSIH in 32.10 seconds
# Creating patches for: TCGA-CK-4948_nonMSIH
# Time elapsed: 13.83 seconds
# Patching completed for TCGA-CK-4948_nonMSIH in 18.52 seconds
# Creating patches for: TCGA-CK-4950_nonMSIH
# Time elapsed: 17.53 seconds
# Patching completed for TCGA-CK-4950_nonMSIH in 31.26 seconds
# Creating patches for: TCGA-CK-4951_MSIH
# Time elapsed: 8.06 seconds
# Patching completed for TCGA-CK-4951_MSIH in 12.90 seconds
# Creating patches for: TCGA-CK-4952_nonMSIH
# Time elapsed: 8.83 seconds
# Patching completed for TCGA-CK-4952_nonMSIH in 18.15 seconds
# Creating patches for: TCGA-CK-5912_nonMSIH
# Time elapsed: 16.11 seconds
# Patching completed for TCGA-CK-5912_nonMSIH in 20.86 seconds
# Creating patches for: TCGA-CK-5913_MSIH
# Time elapsed: 21.21 seconds
# Patching completed for TCGA-CK-5913_MSIH in 29.32 seconds
# Creating patches for: TCGA-CK-5914_nonMSIH
# Time elapsed: 15.06 seconds
# Patching completed for TCGA-CK-5914_nonMSIH in 21.72 seconds
# Creating patches for: TCGA-CK-5915_nonMSIH
# Time elapsed: 24.71 seconds
# Patching completed for TCGA-CK-5915_nonMSIH in 31.37 seconds
# Creating patches for: TCGA-CK-5916_MSIH
# Time elapsed: 23.20 seconds
# Patching completed for TCGA-CK-5916_MSIH in 30.82 seconds
# Creating patches for: TCGA-CK-6746_MSIH
# Time elapsed: 27.13 seconds
# Patching completed for TCGA-CK-6746_MSIH in 36.30 seconds
# Creating patches for: TCGA-CK-6747_MSIH
# Time elapsed: 17.31 seconds
# Patching completed for TCGA-CK-6747_MSIH in 24.06 seconds
# Creating patches for: TCGA-CK-6748_nonMSIH
# Time elapsed: 20.57 seconds
# Patching completed for TCGA-CK-6748_nonMSIH in 31.48 seconds
# Creating patches for: TCGA-CK-6751_nonMSIH
# Time elapsed: 8.70 seconds
# Patching completed for TCGA-CK-6751_nonMSIH in 14.42 seconds
# Creating patches for: TCGA-CL-4957_nonMSIH
# Time elapsed: 13.25 seconds
# Patching completed for TCGA-CL-4957_nonMSIH in 24.19 seconds
# Creating patches for: TCGA-CL-5917_nonMSIH
# Time elapsed: 12.07 seconds
# Patching completed for TCGA-CL-5917_nonMSIH in 20.44 seconds
# Creating patches for: TCGA-CL-5918_nonMSIH
# Time elapsed: 15.01 seconds
# Patching completed for TCGA-CL-5918_nonMSIH in 24.56 seconds
# Creating patches for: TCGA-CM-4743_MSIH
# Time elapsed: 25.45 seconds
# Patching completed for TCGA-CM-4743_MSIH in 33.43 seconds
# Creating patches for: TCGA-CM-4744_nonMSIH
# Time elapsed: 25.38 seconds
# Patching completed for TCGA-CM-4744_nonMSIH in 35.61 seconds
# Creating patches for: TCGA-CM-4746_MSIH
# Time elapsed: 23.42 seconds
# Patching completed for TCGA-CM-4746_MSIH in 38.76 seconds
# Creating patches for: TCGA-CM-4747_nonMSIH
# Time elapsed: 19.20 seconds
# Patching completed for TCGA-CM-4747_nonMSIH in 29.88 seconds
# Creating patches for: TCGA-CM-4750_nonMSIH
# Time elapsed: 24.23 seconds
# Patching completed for TCGA-CM-4750_nonMSIH in 36.26 seconds
# Creating patches for: TCGA-CM-4751_nonMSIH
# Time elapsed: 11.74 seconds
# Patching completed for TCGA-CM-4751_nonMSIH in 17.30 seconds
# Creating patches for: TCGA-CM-4752_nonMSIH
# Time elapsed: 9.88 seconds
# Patching completed for TCGA-CM-4752_nonMSIH in 19.46 seconds
# Creating patches for: TCGA-CM-5341_nonMSIH
# Time elapsed: 10.68 seconds
# Patching completed for TCGA-CM-5341_nonMSIH in 23.28 seconds
# Creating patches for: TCGA-CM-5344_nonMSIH
# Time elapsed: 22.68 seconds
# Patching completed for TCGA-CM-5344_nonMSIH in 33.75 seconds
# Creating patches for: TCGA-CM-5348_nonMSIH
# Time elapsed: 15.00 seconds
# Patching completed for TCGA-CM-5348_nonMSIH in 21.57 seconds
# Creating patches for: TCGA-CM-5349_nonMSIH
# Time elapsed: 21.96 seconds
# Patching completed for TCGA-CM-5349_nonMSIH in 30.93 seconds
# Creating patches for: TCGA-CM-5861_MSIH
# Time elapsed: 10.66 seconds
# Patching completed for TCGA-CM-5861_MSIH in 15.07 seconds
# Creating patches for: TCGA-CM-5862_nonMSIH
# Time elapsed: 13.02 seconds
# Patching completed for TCGA-CM-5862_nonMSIH in 22.76 seconds
# Creating patches for: TCGA-CM-5863_nonMSIH
# Time elapsed: 11.33 seconds
# Patching completed for TCGA-CM-5863_nonMSIH in 21.82 seconds
# Creating patches for: TCGA-CM-5864_nonMSIH
# Time elapsed: 15.01 seconds
# Patching completed for TCGA-CM-5864_nonMSIH in 25.35 seconds
# Creating patches for: TCGA-CM-6161_nonMSIH
# Time elapsed: 19.79 seconds
# Patching completed for TCGA-CM-6161_nonMSIH in 32.80 seconds
# Creating patches for: TCGA-CM-6162_MSIH
# Time elapsed: 12.11 seconds
# Patching completed for TCGA-CM-6162_MSIH in 17.45 seconds
# Creating patches for: TCGA-CM-6164_nonMSIH
# Time elapsed: 11.89 seconds
# Patching completed for TCGA-CM-6164_nonMSIH in 21.34 seconds
# Creating patches for: TCGA-CM-6165_nonMSIH
# Time elapsed: 17.55 seconds
# Patching completed for TCGA-CM-6165_nonMSIH in 28.90 seconds
# Creating patches for: TCGA-CM-6166_nonMSIH
# Time elapsed: 18.74 seconds
# Patching completed for TCGA-CM-6166_nonMSIH in 25.23 seconds
# Creating patches for: TCGA-CM-6167_nonMSIH
# Time elapsed: 13.61 seconds
# Patching completed for TCGA-CM-6167_nonMSIH in 19.77 seconds
# Creating patches for: TCGA-CM-6168_nonMSIH
# Time elapsed: 20.48 seconds
# Patching completed for TCGA-CM-6168_nonMSIH in 31.82 seconds
# Creating patches for: TCGA-CM-6169_nonMSIH
# Time elapsed: 15.76 seconds
# Patching completed for TCGA-CM-6169_nonMSIH in 21.01 seconds
# Creating patches for: TCGA-CM-6170_nonMSIH
# Time elapsed: 8.16 seconds
# Patching completed for TCGA-CM-6170_nonMSIH in 13.31 seconds
# Creating patches for: TCGA-CM-6171_MSIH
# Time elapsed: 18.77 seconds
# Patching completed for TCGA-CM-6171_MSIH in 26.67 seconds
# Creating patches for: TCGA-CM-6172_nonMSIH
# Time elapsed: 10.68 seconds
# Patching completed for TCGA-CM-6172_nonMSIH in 17.51 seconds
# Creating patches for: TCGA-CM-6674_MSIH
# Time elapsed: 19.00 seconds
# Patching completed for TCGA-CM-6674_MSIH in 30.96 seconds
# Creating patches for: TCGA-CM-6675_nonMSIH
# Time elapsed: 23.06 seconds
# Patching completed for TCGA-CM-6675_nonMSIH in 32.08 seconds
# Creating patches for: TCGA-CM-6676_nonMSIH
# Time elapsed: 10.88 seconds
# Patching completed for TCGA-CM-6676_nonMSIH in 16.76 seconds
# Creating patches for: TCGA-CM-6677_nonMSIH
# Time elapsed: 15.95 seconds
# Patching completed for TCGA-CM-6677_nonMSIH in 26.08 seconds
# Creating patches for: TCGA-CM-6678_nonMSIH
# Time elapsed: 8.47 seconds
# Patching completed for TCGA-CM-6678_nonMSIH in 12.44 seconds
# Creating patches for: TCGA-CM-6679_nonMSIH
# Time elapsed: 15.01 seconds
# Patching completed for TCGA-CM-6679_nonMSIH in 24.30 seconds
# Creating patches for: TCGA-CM-6680_nonMSIH
# Time elapsed: 21.52 seconds
# Patching completed for TCGA-CM-6680_nonMSIH in 35.44 seconds
# Creating patches for: TCGA-D5-5537_nonMSIH
# Time elapsed: 2.53 seconds
# Patching completed for TCGA-D5-5537_nonMSIH in 3.67 seconds
# Creating patches for: TCGA-D5-5538_nonMSIH
# Time elapsed: 12.94 seconds
# Patching completed for TCGA-D5-5538_nonMSIH in 18.45 seconds
# Creating patches for: TCGA-D5-5539_nonMSIH
# Time elapsed: 5.50 seconds
# Patching completed for TCGA-D5-5539_nonMSIH in 10.66 seconds
# Creating patches for: TCGA-D5-5540_nonMSIH
# Time elapsed: 13.22 seconds
# Patching completed for TCGA-D5-5540_nonMSIH in 19.69 seconds
# Creating patches for: TCGA-D5-5541_nonMSIH
# Time elapsed: 9.24 seconds
# Patching completed for TCGA-D5-5541_nonMSIH in 17.45 seconds
# Creating patches for: TCGA-D5-6529_nonMSIH
# Time elapsed: 10.25 seconds
# Patching completed for TCGA-D5-6529_nonMSIH in 14.52 seconds
# Creating patches for: TCGA-D5-6530_MSIH
# Time elapsed: 19.42 seconds
# Patching completed for TCGA-D5-6530_MSIH in 29.85 seconds
# Creating patches for: TCGA-D5-6531_nonMSIH
# Time elapsed: 7.00 seconds
# Patching completed for TCGA-D5-6531_nonMSIH in 10.36 seconds
# Creating patches for: TCGA-D5-6532_nonMSIH
# Time elapsed: 3.76 seconds
# Patching completed for TCGA-D5-6532_nonMSIH in 5.14 seconds
# Creating patches for: TCGA-D5-6533_nonMSIH
# Time elapsed: 6.31 seconds
# Patching completed for TCGA-D5-6533_nonMSIH in 14.42 seconds
# Creating patches for: TCGA-D5-6534_nonMSIH
# Time elapsed: 3.88 seconds
# Patching completed for TCGA-D5-6534_nonMSIH in 6.42 seconds
# Creating patches for: TCGA-D5-6535_nonMSIH
# Time elapsed: 3.52 seconds
# Patching completed for TCGA-D5-6535_nonMSIH in 10.97 seconds
# Creating patches for: TCGA-D5-6536_nonMSIH
# Time elapsed: 4.70 seconds
# Patching completed for TCGA-D5-6536_nonMSIH in 7.40 seconds
# Creating patches for: TCGA-D5-6537_nonMSIH
# Time elapsed: 4.11 seconds
# Patching completed for TCGA-D5-6537_nonMSIH in 5.75 seconds
# Creating patches for: TCGA-D5-6538_nonMSIH
# Time elapsed: 8.16 seconds
# Patching completed for TCGA-D5-6538_nonMSIH in 15.07 seconds
# Creating patches for: TCGA-D5-6539_nonMSIH
# Time elapsed: 4.61 seconds
# Patching completed for TCGA-D5-6539_nonMSIH in 7.03 seconds
# Creating patches for: TCGA-D5-6540_MSIH
# Time elapsed: 5.97 seconds
# Patching completed for TCGA-D5-6540_MSIH in 9.25 seconds
# Creating patches for: TCGA-D5-6541_nonMSIH
# Time elapsed: 4.78 seconds
# Patching completed for TCGA-D5-6541_nonMSIH in 7.03 seconds
# Creating patches for: TCGA-D5-6898_nonMSIH
# Time elapsed: 0.87 seconds
# Patching completed for TCGA-D5-6898_nonMSIH in 5.62 seconds
# Creating patches for: TCGA-D5-6922_nonMSIH
# Time elapsed: 0.61 seconds
# Patching completed for TCGA-D5-6922_nonMSIH in 0.91 seconds
# Creating patches for: TCGA-D5-6924_nonMSIH
# Time elapsed: 1.10 seconds
# Patching completed for TCGA-D5-6924_nonMSIH in 1.71 seconds
# Creating patches for: TCGA-D5-6926_nonMSIH
# Time elapsed: 0.96 seconds
# Patching completed for TCGA-D5-6926_nonMSIH in 1.40 seconds
# Creating patches for: TCGA-D5-6927_MSIH
# Time elapsed: 4.28 seconds
# Patching completed for TCGA-D5-6927_MSIH in 5.99 seconds
# Creating patches for: TCGA-D5-6928_MSIH
# Time elapsed: 2.10 seconds
# Patching completed for TCGA-D5-6928_MSIH in 3.16 seconds
# Creating patches for: TCGA-D5-6929_nonMSIH
# Time elapsed: 3.96 seconds
# Patching completed for TCGA-D5-6929_nonMSIH in 6.81 seconds
# Creating patches for: TCGA-D5-6930_MSIH
# Time elapsed: 0.66 seconds
# Patching completed for TCGA-D5-6930_MSIH in 1.08 seconds
# Creating patches for: TCGA-D5-6931_nonMSIH
# Time elapsed: 1.79 seconds
# Patching completed for TCGA-D5-6931_nonMSIH in 2.49 seconds
# Creating patches for: TCGA-D5-6932_nonMSIH
# Time elapsed: 1.25 seconds
# Patching completed for TCGA-D5-6932_nonMSIH in 1.77 seconds
# Creating patches for: TCGA-D5-7000_nonMSIH
# Time elapsed: 0.91 seconds
# Patching completed for TCGA-D5-7000_nonMSIH in 1.40 seconds
# Creating patches for: TCGA-DC-4745_nonMSIH
# Time elapsed: 14.03 seconds
# Patching completed for TCGA-DC-4745_nonMSIH in 23.32 seconds
# Creating patches for: TCGA-DC-4749_nonMSIH
# Time elapsed: 14.96 seconds
# Patching completed for TCGA-DC-4749_nonMSIH in 27.17 seconds
# Creating patches for: TCGA-DC-5337_nonMSIH
# Time elapsed: 7.61 seconds
# Patching completed for TCGA-DC-5337_nonMSIH in 10.79 seconds
# Creating patches for: TCGA-DC-5869_nonMSIH
# Time elapsed: 22.71 seconds
# Patching completed for TCGA-DC-5869_nonMSIH in 33.07 seconds
# Creating patches for: TCGA-DC-6154_MSIH
# Time elapsed: 10.30 seconds
# Patching completed for TCGA-DC-6154_MSIH in 14.27 seconds
# Creating patches for: TCGA-DC-6157_nonMSIH
# Time elapsed: 10.98 seconds
# Patching completed for TCGA-DC-6157_nonMSIH in 20.06 seconds
# Creating patches for: TCGA-DC-6158_nonMSIH
# Time elapsed: 11.52 seconds
# Patching completed for TCGA-DC-6158_nonMSIH in 23.12 seconds
# Creating patches for: TCGA-DC-6160_nonMSIH
# Time elapsed: 15.37 seconds
# Patching completed for TCGA-DC-6160_nonMSIH in 25.08 seconds
# Creating patches for: TCGA-DC-6681_nonMSIH
# Time elapsed: 23.34 seconds
# Patching completed for TCGA-DC-6681_nonMSIH in 36.58 seconds
# Creating patches for: TCGA-DC-6682_nonMSIH
# Time elapsed: 9.74 seconds
# Patching completed for TCGA-DC-6682_nonMSIH in 14.16 seconds
# Creating patches for: TCGA-DC-6683_nonMSIH
# Time elapsed: 13.97 seconds
# Patching completed for TCGA-DC-6683_nonMSIH in 22.51 seconds
# Creating patches for: TCGA-DM-A0X9_nonMSIH
# Time elapsed: 14.07 seconds
# Patching completed for TCGA-DM-A0X9_nonMSIH in 22.64 seconds
# Creating patches for: TCGA-DM-A0XD_nonMSIH
# Time elapsed: 2.92 seconds
# Patching completed for TCGA-DM-A0XD_nonMSIH in 5.27 seconds
# Creating patches for: TCGA-DM-A0XF_nonMSIH
# Time elapsed: 11.93 seconds
# Patching completed for TCGA-DM-A0XF_nonMSIH in 16.14 seconds
# Creating patches for: TCGA-DM-A1D0_nonMSIH
# Time elapsed: 15.09 seconds
# Patching completed for TCGA-DM-A1D0_nonMSIH in 25.53 seconds
# Creating patches for: TCGA-DM-A1D4_nonMSIH
# Time elapsed: 11.06 seconds
# Patching completed for TCGA-DM-A1D4_nonMSIH in 17.46 seconds
# Creating patches for: TCGA-DM-A1D6_nonMSIH
# Time elapsed: 13.04 seconds
# Patching completed for TCGA-DM-A1D6_nonMSIH in 21.09 seconds
# Creating patches for: TCGA-DM-A1D7_nonMSIH
# Time elapsed: 7.82 seconds
# Patching completed for TCGA-DM-A1D7_nonMSIH in 17.44 seconds
# Creating patches for: TCGA-DM-A1D8_nonMSIH
# Time elapsed: 4.24 seconds
# Patching completed for TCGA-DM-A1D8_nonMSIH in 5.92 seconds
# Creating patches for: TCGA-DM-A1D9_nonMSIH
# Time elapsed: 12.73 seconds
# Patching completed for TCGA-DM-A1D9_nonMSIH in 26.29 seconds
# Creating patches for: TCGA-DM-A1DA_nonMSIH
# Time elapsed: 10.20 seconds
# Patching completed for TCGA-DM-A1DA_nonMSIH in 19.15 seconds
# Creating patches for: TCGA-DM-A1DB_nonMSIH
# Time elapsed: 20.05 seconds
# Patching completed for TCGA-DM-A1DB_nonMSIH in 31.78 seconds
# Creating patches for: TCGA-DM-A1HA_nonMSIH
# Time elapsed: 13.73 seconds
# Patching completed for TCGA-DM-A1HA_nonMSIH in 19.42 seconds
# Creating patches for: TCGA-DM-A282_nonMSIH
# Time elapsed: 23.61 seconds
# Patching completed for TCGA-DM-A282_nonMSIH in 35.96 seconds
# Creating patches for: TCGA-DM-A285_nonMSIH
# Time elapsed: 14.62 seconds
# Patching completed for TCGA-DM-A285_nonMSIH in 24.49 seconds
# Creating patches for: TCGA-DM-A288_nonMSIH
# Time elapsed: 17.23 seconds
# Patching completed for TCGA-DM-A288_nonMSIH in 28.85 seconds
# Creating patches for: TCGA-DM-A28A_nonMSIH
# Time elapsed: 13.84 seconds
# Patching completed for TCGA-DM-A28A_nonMSIH in 19.99 seconds
# Creating patches for: TCGA-DM-A28E_nonMSIH
# Time elapsed: 14.41 seconds
# Patching completed for TCGA-DM-A28E_nonMSIH in 22.29 seconds
# Creating patches for: TCGA-DM-A28F_nonMSIH
# Time elapsed: 7.31 seconds
# Patching completed for TCGA-DM-A28F_nonMSIH in 15.38 seconds
# Creating patches for: TCGA-DM-A28G_nonMSIH
# Time elapsed: 10.60 seconds
# Patching completed for TCGA-DM-A28G_nonMSIH in 16.10 seconds
# Creating patches for: TCGA-DM-A28H_nonMSIH
# Time elapsed: 8.53 seconds
# Patching completed for TCGA-DM-A28H_nonMSIH in 11.56 seconds
# Creating patches for: TCGA-DM-A28K_nonMSIH
# Time elapsed: 19.72 seconds
# Patching completed for TCGA-DM-A28K_nonMSIH in 32.81 seconds
# Creating patches for: TCGA-DM-A28M_nonMSIH
# Time elapsed: 8.10 seconds
# Patching completed for TCGA-DM-A28M_nonMSIH in 12.55 seconds
# Creating patches for: TCGA-DT-5265_nonMSIH
# Time elapsed: 6.58 seconds
# Patching completed for TCGA-DT-5265_nonMSIH in 9.73 seconds
# Creating patches for: TCGA-DY-A0XA_nonMSIH
# Time elapsed: 21.40 seconds
# Patching completed for TCGA-DY-A0XA_nonMSIH in 33.96 seconds
# Creating patches for: TCGA-DY-A1DC_nonMSIH
# Time elapsed: 11.54 seconds
# Patching completed for TCGA-DY-A1DC_nonMSIH in 15.89 seconds
# Creating patches for: TCGA-DY-A1DD_nonMSIH
# Time elapsed: 27.43 seconds
# Patching completed for TCGA-DY-A1DD_nonMSIH in 38.89 seconds
# Creating patches for: TCGA-DY-A1DF_nonMSIH
# Time elapsed: 8.99 seconds
# Patching completed for TCGA-DY-A1DF_nonMSIH in 12.71 seconds
# Creating patches for: TCGA-DY-A1DG_nonMSIH
# Time elapsed: 24.63 seconds
# Patching completed for TCGA-DY-A1DG_nonMSIH in 34.48 seconds
# Creating patches for: TCGA-EF-5830_nonMSIH
# Time elapsed: 14.29 seconds
# Patching completed for TCGA-EF-5830_nonMSIH in 22.42 seconds
# Creating patches for: TCGA-EI-6506_nonMSIH
# Time elapsed: 7.82 seconds
# Patching completed for TCGA-EI-6506_nonMSIH in 14.40 seconds
# Creating patches for: TCGA-EI-6507_MSIH
# Time elapsed: 10.99 seconds
# Patching completed for TCGA-EI-6507_MSIH in 15.51 seconds
# Creating patches for: TCGA-EI-6508_nonMSIH
# Time elapsed: 12.12 seconds
# Patching completed for TCGA-EI-6508_nonMSIH in 19.66 seconds
# Creating patches for: TCGA-EI-6509_nonMSIH
# Time elapsed: 4.09 seconds
# Patching completed for TCGA-EI-6509_nonMSIH in 6.80 seconds
# Creating patches for: TCGA-EI-6510_nonMSIH
# Time elapsed: 11.87 seconds
# Patching completed for TCGA-EI-6510_nonMSIH in 18.96 seconds
# Creating patches for: TCGA-EI-6511_nonMSIH
# Time elapsed: 23.39 seconds
# Patching completed for TCGA-EI-6511_nonMSIH in 36.24 seconds
# Creating patches for: TCGA-EI-6512_nonMSIH
# Time elapsed: 13.12 seconds
# Patching completed for TCGA-EI-6512_nonMSIH in 19.85 seconds
# Creating patches for: TCGA-EI-6513_nonMSIH
# Time elapsed: 3.50 seconds
# Patching completed for TCGA-EI-6513_nonMSIH in 6.22 seconds
# Creating patches for: TCGA-EI-6514_nonMSIH
# Time elapsed: 6.35 seconds
# Patching completed for TCGA-EI-6514_nonMSIH in 9.84 seconds
# Creating patches for: TCGA-EI-6881_nonMSIH
# Time elapsed: 0.51 seconds
# Patching completed for TCGA-EI-6881_nonMSIH in 0.75 seconds
# Creating patches for: TCGA-EI-6882_MSIH
# Time elapsed: 1.33 seconds
# Patching completed for TCGA-EI-6882_MSIH in 1.94 seconds
# Creating patches for: TCGA-EI-6883_nonMSIH
# Time elapsed: 8.45 seconds
# Patching completed for TCGA-EI-6883_nonMSIH in 17.54 seconds
# Creating patches for: TCGA-EI-6884_nonMSIH
# Time elapsed: 1.12 seconds
# Patching completed for TCGA-EI-6884_nonMSIH in 2.02 seconds
# Creating patches for: TCGA-EI-6885_nonMSIH
# Time elapsed: 2.89 seconds
# Patching completed for TCGA-EI-6885_nonMSIH in 4.32 seconds
# Creating patches for: TCGA-EI-6917_nonMSIH
# Time elapsed: 1.37 seconds
# Patching completed for TCGA-EI-6917_nonMSIH in 1.86 seconds
# Creating patches for: TCGA-EI-7002_nonMSIH
# Time elapsed: 0.90 seconds
# Patching completed for TCGA-EI-7002_nonMSIH in 3.60 seconds
# Creating patches for: TCGA-EI-7004_nonMSIH
# Time elapsed: 0.56 seconds
# Patching completed for TCGA-EI-7004_nonMSIH in 4.44 seconds
# Creating patches for: TCGA-F4-6459_nonMSIH
# Time elapsed: 17.99 seconds
# Patching completed for TCGA-F4-6459_nonMSIH in 23.78 seconds
# Creating patches for: TCGA-F4-6460_nonMSIH
# Time elapsed: 15.67 seconds
# Patching completed for TCGA-F4-6460_nonMSIH in 24.00 seconds
# Creating patches for: TCGA-F4-6461_nonMSIH
# Time elapsed: 11.03 seconds
# Patching completed for TCGA-F4-6461_nonMSIH in 19.70 seconds
# Creating patches for: TCGA-F4-6463_nonMSIH
# Time elapsed: 7.02 seconds
# Patching completed for TCGA-F4-6463_nonMSIH in 11.13 seconds
# Creating patches for: TCGA-F4-6569_nonMSIH
# Time elapsed: 10.69 seconds
# Patching completed for TCGA-F4-6569_nonMSIH in 16.03 seconds
# Creating patches for: TCGA-F4-6570_MSIH
# Time elapsed: 13.92 seconds
# Patching completed for TCGA-F4-6570_MSIH in 21.60 seconds
# Creating patches for: TCGA-F4-6703_MSIH
# Time elapsed: 9.64 seconds
# Patching completed for TCGA-F4-6703_MSIH in 15.69 seconds
# Creating patches for: TCGA-F4-6704_nonMSIH
# Time elapsed: 8.71 seconds
# Patching completed for TCGA-F4-6704_nonMSIH in 22.76 seconds
# Creating patches for: TCGA-F4-6805_nonMSIH
# Time elapsed: 8.17 seconds
# Patching completed for TCGA-F4-6805_nonMSIH in 32.60 seconds
# Creating patches for: TCGA-F4-6806_nonMSIH
# Time elapsed: 13.11 seconds
# Patching completed for TCGA-F4-6806_nonMSIH in 20.25 seconds
# Creating patches for: TCGA-F4-6807_nonMSIH
# Time elapsed: 20.98 seconds
# Patching completed for TCGA-F4-6807_nonMSIH in 33.02 seconds
# Creating patches for: TCGA-F4-6808_nonMSIH
# Time elapsed: 21.41 seconds
# Patching completed for TCGA-F4-6808_nonMSIH in 28.45 seconds
# Creating patches for: TCGA-F4-6809_nonMSIH
# Time elapsed: 15.28 seconds
# Patching completed for TCGA-F4-6809_nonMSIH in 22.96 seconds
# Creating patches for: TCGA-F4-6854_nonMSIH
# Time elapsed: 7.43 seconds
# Patching completed for TCGA-F4-6854_nonMSIH in 10.28 seconds
# Creating patches for: TCGA-F4-6855_nonMSIH
# Time elapsed: 4.37 seconds
# Patching completed for TCGA-F4-6855_nonMSIH in 12.76 seconds
# Creating patches for: TCGA-F4-6856_MSIH
# Time elapsed: 11.08 seconds
# Patching completed for TCGA-F4-6856_MSIH in 15.41 seconds
# Creating patches for: TCGA-F5-6464_nonMSIH
# Time elapsed: 6.36 seconds
# Patching completed for TCGA-F5-6464_nonMSIH in 13.70 seconds
# Creating patches for: TCGA-F5-6465_nonMSIH
# Time elapsed: 10.76 seconds
# Patching completed for TCGA-F5-6465_nonMSIH in 13.59 seconds
# Creating patches for: TCGA-F5-6571_nonMSIH
# Time elapsed: 8.02 seconds
# Patching completed for TCGA-F5-6571_nonMSIH in 12.49 seconds
# Creating patches for: TCGA-F5-6702_nonMSIH
# Time elapsed: 10.39 seconds
# Patching completed for TCGA-F5-6702_nonMSIH in 19.46 seconds
# Creating patches for: TCGA-F5-6811_nonMSIH
# Time elapsed: 3.09 seconds
# Patching completed for TCGA-F5-6811_nonMSIH in 4.46 seconds
# Creating patches for: TCGA-F5-6814_nonMSIH
# Time elapsed: 10.02 seconds
# Patching completed for TCGA-F5-6814_nonMSIH in 15.99 seconds
# Creating patches for: TCGA-F5-6863_nonMSIH
# Time elapsed: 11.19 seconds
# Patching completed for TCGA-F5-6863_nonMSIH in 15.18 seconds
# Creating patches for: TCGA-F5-6864_nonMSIH
# Time elapsed: 6.97 seconds
# Patching completed for TCGA-F5-6864_nonMSIH in 12.84 seconds
# Creating patches for: TCGA-G4-6293_nonMSIH
# Time elapsed: 11.74 seconds
# Patching completed for TCGA-G4-6293_nonMSIH in 16.03 seconds
# Creating patches for: TCGA-G4-6294_nonMSIH
# Time elapsed: 6.46 seconds
# Patching completed for TCGA-G4-6294_nonMSIH in 13.79 seconds
# Creating patches for: TCGA-G4-6295_nonMSIH
# Time elapsed: 11.02 seconds
# Patching completed for TCGA-G4-6295_nonMSIH in 17.24 seconds
# Creating patches for: TCGA-G4-6297_nonMSIH
# Time elapsed: 20.14 seconds
# Patching completed for TCGA-G4-6297_nonMSIH in 30.72 seconds
# Creating patches for: TCGA-G4-6298_nonMSIH
# Time elapsed: 14.20 seconds
# Patching completed for TCGA-G4-6298_nonMSIH in 20.85 seconds
# Creating patches for: TCGA-G4-6299_nonMSIH
# Time elapsed: 3.98 seconds
# Patching completed for TCGA-G4-6299_nonMSIH in 10.20 seconds
# Creating patches for: TCGA-G4-6302_MSIH
# Time elapsed: 10.01 seconds
# Patching completed for TCGA-G4-6302_MSIH in 14.10 seconds
# Creating patches for: TCGA-G4-6303_nonMSIH
# Time elapsed: 9.29 seconds
# Patching completed for TCGA-G4-6303_nonMSIH in 18.18 seconds
# Creating patches for: TCGA-G4-6304_MSIH
# Time elapsed: 8.25 seconds
# Patching completed for TCGA-G4-6304_MSIH in 11.63 seconds
# Creating patches for: TCGA-G4-6306_nonMSIH
# Time elapsed: 10.91 seconds
# Patching completed for TCGA-G4-6306_nonMSIH in 20.38 seconds
# Creating patches for: TCGA-G4-6307_nonMSIH
# Time elapsed: 10.86 seconds
# Patching completed for TCGA-G4-6307_nonMSIH in 22.68 seconds
# Creating patches for: TCGA-G4-6309_MSIH
# Time elapsed: 7.67 seconds
# Patching completed for TCGA-G4-6309_MSIH in 17.22 seconds
# Creating patches for: TCGA-G4-6311_nonMSIH
# Time elapsed: 15.37 seconds
# Patching completed for TCGA-G4-6311_nonMSIH in 22.29 seconds
# Creating patches for: TCGA-G4-6315_nonMSIH
# Time elapsed: 6.78 seconds
# Patching completed for TCGA-G4-6315_nonMSIH in 12.40 seconds
# Creating patches for: TCGA-G4-6317_nonMSIH
# Time elapsed: 9.56 seconds
# Patching completed for TCGA-G4-6317_nonMSIH in 17.99 seconds
# Creating patches for: TCGA-G4-6320_MSIH
# Time elapsed: 4.02 seconds
# Patching completed for TCGA-G4-6320_MSIH in 5.73 seconds
# Creating patches for: TCGA-G4-6321_nonMSIH
# Time elapsed: 10.35 seconds
# Patching completed for TCGA-G4-6321_nonMSIH in 18.81 seconds
# Creating patches for: TCGA-G4-6322_nonMSIH
# Time elapsed: 3.95 seconds
# Patching completed for TCGA-G4-6322_nonMSIH in 6.76 seconds
# Creating patches for: TCGA-G4-6323_nonMSIH
# Time elapsed: 8.54 seconds
# Patching completed for TCGA-G4-6323_nonMSIH in 17.81 seconds
# Creating patches for: TCGA-G4-6586_MSIH
# Time elapsed: 15.71 seconds
# Patching completed for TCGA-G4-6586_MSIH in 21.62 seconds
# Creating patches for: TCGA-G4-6588_MSIH
# Time elapsed: 8.25 seconds
# Patching completed for TCGA-G4-6588_MSIH in 15.15 seconds
# Creating patches for: TCGA-G4-6626_nonMSIH
# Time elapsed: 8.10 seconds
# Patching completed for TCGA-G4-6626_nonMSIH in 16.68 seconds
# Creating patches for: TCGA-G4-6627_nonMSIH
# Time elapsed: 8.33 seconds
# Patching completed for TCGA-G4-6627_nonMSIH in 13.01 seconds
# Creating patches for: TCGA-G4-6628_MSIH
# Time elapsed: 1.94 seconds
# Patching completed for TCGA-G4-6628_MSIH in 4.49 seconds
# Creating patches for: TCGA-G5-6641_nonMSIH
# Time elapsed: 6.35 seconds
# Patching completed for TCGA-G5-6641_nonMSIH in 14.48 seconds
# Creating patches for: TCGA-NH-A50T_nonMSIH
# Time elapsed: 15.13 seconds
# Patching completed for TCGA-NH-A50T_nonMSIH in 21.37 seconds
# Creating patches for: TCGA-NH-A50U_nonMSIH
# Time elapsed: 10.23 seconds
# Patching completed for TCGA-NH-A50U_nonMSIH in 17.48 seconds
# Creating patches for: TCGA-NH-A50V_nonMSIH
# Time elapsed: 15.56 seconds
# Patching completed for TCGA-NH-A50V_nonMSIH in 28.87 seconds
# Creating patches for: TCGA-NH-A5IV_MSIH
# Time elapsed: 16.21 seconds
# Patching completed for TCGA-NH-A5IV_MSIH in 22.25 seconds
# Creating patches for: TCGA-NH-A6GA_nonMSIH
# Time elapsed: 14.02 seconds
# Patching completed for TCGA-NH-A6GA_nonMSIH in 22.81 seconds
# Creating patches for: TCGA-NH-A6GB_nonMSIH
# Time elapsed: 17.92 seconds
# Patching completed for TCGA-NH-A6GB_nonMSIH in 28.95 seconds
# Creating patches for: TCGA-NH-A6GC_nonMSIH
# Time elapsed: 14.44 seconds
# Patching completed for TCGA-NH-A6GC_nonMSIH in 18.68 seconds
# Creating patches for: TCGA-NH-A8F8_nonMSIH
# Time elapsed: 10.86 seconds
# Patching completed for TCGA-NH-A8F8_nonMSIH in 15.76 seconds
# Creating patches for: TCGA-QG-A5YV_nonMSIH
# Time elapsed: 22.51 seconds
# Patching completed for TCGA-QG-A5YV_nonMSIH in 36.33 seconds
# Creating patches for: TCGA-QG-A5YX_nonMSIH
# Time elapsed: 12.01 seconds
# Patching completed for TCGA-QG-A5YX_nonMSIH in 16.89 seconds
# Creating patches for: TCGA-QG-A5Z1_nonMSIH
# Time elapsed: 9.92 seconds
# Patching completed for TCGA-QG-A5Z1_nonMSIH in 18.88 seconds
# Creating patches for: TCGA-QG-A5Z2_MSIH
# Time elapsed: 13.93 seconds
# Patching completed for TCGA-QG-A5Z2_MSIH in 19.51 seconds
# Creating patches for: TCGA-QL-A97D_nonMSIH
# Time elapsed: 16.31 seconds
# Patching completed for TCGA-QL-A97D_nonMSIH in 27.96 seconds
# Creating patches for: TCGA-SS-A7HO_nonMSIH
# Time elapsed: 20.78 seconds
# Patching completed for TCGA-SS-A7HO_nonMSIH in 28.65 seconds
# Creating patches for: TCGA-T9-A92H_nonMSIH
# Time elapsed: 2.87 seconds
# Patching completed for TCGA-T9-A92H_nonMSIH in 4.05 seconds
# Creating patches for: TCGA-WS-AB45_MSIH
# Time elapsed: 15.88 seconds
# Patching completed for TCGA-WS-AB45_MSIH in 21.76 seconds
